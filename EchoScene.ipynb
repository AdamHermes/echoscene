# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !rm -rf echoscene
# !git clone https://github.com/AdamHermes/echoscene.git
# %cd echoscene
# Out:
# /content
# Cloning into 'echoscene'...
# remote: Enumerating objects: 2079, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 2079 (delta 191), reused 172 (delta 167), pack-reused 1845 (from 3)
# Receiving objects: 100% (2079/2079), 77.45 MiB | 20.16 MiB/s, done.
# Resolving deltas: 100% (1412/1412), done.
# /content/echoscene

# %%
# !git switch physcene_fusion
# !git switch real_current_best
# Out:
# Branch 'real_current_best' set up to track remote branch 'real_current_best' from 'origin'.
# Switched to a new branch 'real_current_best'

# %%
# !gdown "13p_1wUHH0G0sEHzViXmF7RVuO6WGeb_5"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=13p_1wUHH0G0sEHzViXmF7RVuO6WGeb_5
# From (redirected): https://drive.google.com/uc?id=13p_1wUHH0G0sEHzViXmF7RVuO6WGeb_5&confirm=t&uuid=31b756d0-3a2d-456c-b49a-a97bdf5fca4a
# To: /content/echoscene/FRONT.zip
# 100% 5.94G/5.94G [01:03<00:00, 94.0MB/s]

# %%
# !unzip -q FRONT.zip

# %%
# !mkdir -p scripts/checkpoint
# !wget https://www.campar.in.tum.de/public_datasets/2023_commonscenes_zhai/vqvae_threedfront_best.pth -P scripts/checkpoint
# Out:
# --2026-07-20 13:01:07--  https://www.campar.in.tum.de/public_datasets/2023_commonscenes_zhai/vqvae_threedfront_best.pth
# Resolving www.campar.in.tum.de (www.campar.in.tum.de)... 131.159.10.233, 2a09:80c0:10::233
# Connecting to www.campar.in.tum.de (www.campar.in.tum.de)|131.159.10.233|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105446839 (101M) [application/octet-stream]
# Saving to: ‘scripts/checkpoint/vqvae_threedfront_best.pth’
#
# vqvae_threedfront_b 100%[===================>] 100.56M  21.0MB/s    in 5.7s
#
# 2026-07-20 13:01:14 (17.6 MB/s) - ‘scripts/checkpoint/vqvae_threedfront_best.pth’ saved [105446839/105446839]

# %%
# !pwd
# Out:
# /content/echoscene

# %%
# !wget https://www.campar.in.tum.de/public_datasets/2024_echoscene/released_full_model.zip -O released_full_model.zip
# !unzip released_full_model.zip

# %%
# Install gdown (if not already installed)
# !pip install -q gdown

# Download the file from Google Drive
# !gdown 14tyQhl424zsyQL_0lMkeWFBvYnDXqzue -O released_full_model.zip

# Unzip
# !unzip -q released_full_model.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=14tyQhl424zsyQL_0lMkeWFBvYnDXqzue
# From (redirected): https://drive.google.com/uc?id=14tyQhl424zsyQL_0lMkeWFBvYnDXqzue&confirm=t&uuid=7ff7416f-722a-4cc5-aff1-51d92be73871
# To: /content/echoscene/released_full_model.zip
# 100% 6.30G/6.30G [01:05<00:00, 96.4MB/s]

# %%
# !rm -f /content/echoscene/checkpoint.zip
# !rm -f /content/echoscene/released_full_model.zip

# %%
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -u -p /usr/local/miniconda3

# !/usr/local/miniconda3/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# !/usr/local/miniconda3/bin/conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r

# !/usr/local/miniconda3/bin/conda create -n echoscene python=3.8 -y
# Out:
# PREFIX=/usr/local/miniconda3
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local/miniconda3
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/miniconda3/envs/echoscene
#
#   added / updated specs:
#     - python=3.8
#
#
# ...

# %%
# Make sure we are in the right folder (using %cd so it is permanent)
# %cd /content/echoscene

# Install requirements
# !/usr/local/miniconda3/envs/echoscene/bin/pip install -r requirements.txt

# Install other packages using the Conda pip
# !/usr/local/miniconda3/envs/echoscene/bin/pip install einops omegaconf tensorboardx open3d ftfy regex tqdm
# !/usr/local/miniconda3/envs/echoscene/bin/pip install git+https://github.com/openai/CLIP.git

# Install PyTorch for CUDA 11.3
# !/usr/local/miniconda3/envs/echoscene/bin/pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113
# alternatively pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2 --extra-index-url https://download.pytorch.org/whl/cu118

# Install PyTorch3D
# !/usr/local/miniconda3/envs/echoscene/bin/pip install --no-index --no-cache-dir pytorch3d -f https://dl.fbaipublicfiles.com/pytorch3d/packaging/wheels/py38_cu113_pyt1110/download.html
# alternatively pip install "git+https://github.com/facebookresearch/pytorch3d.git@v0.7.4" --no-build-isolation
# Out:
# /content/echoscene
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 73.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 95.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 79.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 58.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 746.5/746.5 kB 40.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 174.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 72.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 741.0/741.0 kB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 124.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/13.9 MB 121.2 MB/s eta 0:00:00
# ...

# %%
# %cd scripts
# !pwd
# Out:
# /content/echoscene/scripts
# /content/echoscene/scripts

# %%
# !pip install trimesh
# Out:
# ...
#   Using cached trimesh-4.12.2-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached trimesh-4.12.2-py3-none-any.whl (741 kB)
# ...

# %%
print("Hello")
# Out:
# Hello

# %%
# Map the checkpoint and config paths if not already done
# !ln -sfn /content/echoscene/scripts/checkpoint /content/echoscene/checkpoint
# !rm -rf /content/config && ln -s /content/echoscene/config /content/config

# Run the evaluation with PYTHONPATH set to the project root
# !PYTHONPATH=/content/echoscene /usr/local/miniconda3/envs/echoscene/bin/python eval_3dfront.py \
    --exp ../released_full_model \
    --dataset ../FRONT/ \
    --epoch 2050 \
    --visualize True \
    --room_type all \
    --render_type echoscene \
    --gen_shape True \
    --max_samples 25 \
    --start_idx 350 \
    --debug True
# Out:
# 1.11.0+cu113
# 100%|████████████████████████████████████████| 338M/338M [00:01<00:00, 192MiB/s]
# loading CLIP
# Checking for missing clip feats. This can be slow the first time.
# 100% 370/370 [00:26<00:00, 14.03it/s]
# Working with z of shape (1, 3, 16, 16, 16) = 12288 dimensions.
# [*] VQVAE: weight successfully load from: ./checkpoint/vqvae_threedfront_best.pth
# [*] setting ddim_steps=100
# [*] create image directory:
# /content/echoscene/full_mp/diff_crossattn/images...
# [*] shape branch has successfully been restored from: ../released_full_model/checkpoint/model2050.pth
# [*] GCN and layout branch has successfully been restored from: ../released_full_model/checkpoint/model2050.pth
# Evaluating 20 sample(s)
#
# Editing Mode - Additions
#
# Editing Mode - Relationship changes
#
# Generation Mode
# ['Library-163346']
# 1000it [01:15, 13.24it/s]
# inference mode.. no gt sdf
# Data shape for DDIM sampling is (5, 3, 16, 16, 16), eta 0.0
# Running DDIM Sampling with 100 timesteps
# ...

# %%
# !cp -r "/content/echoscene/released_full_model/vis" "/content/drive/MyDrive/EchoScene/phy3"

# %%
# Navigate to the echoscene directory
# %cd /content/echoscene

# Zip the 'vis' folder within 'released_full_model'
# !zip -r vis_folder_idx50_range25.zip released_full_model/vis

print("vis_folder.zip created in /content/echoscene/")

# %%
import shutil
import os

# Source path in Colab
source_zip = '/content/echoscene/vis_folder_idx50_range25.zip'

# Destination path in Google Drive (using the variable ECHOSCENE_PATH if defined, or hardcoding it)
drive_destination = '/content/drive/MyDrive/EchoScene/vis_folder.zip'

# Ensure the destination directory exists
os.makedirs(os.path.dirname(drive_destination), exist_ok=True)

# Copy the file to Drive
shutil.copy2(source_zip, drive_destination)
print(f'Successfully backed up {source_zip} to {drive_destination}')

# %%
from google.colab import files

# Path to the zipped folder
zip_file_path = '/content/echoscene/vis_folder.zip'

# Download the file
files.download(zip_file_path)

# %%
# !rm -rf released_full_model/vis

# %% [markdown]
# To download the `vis_folder.zip` file:
#
# 1.  **Look for the Files icon** (a folder icon) on the left sidebar of your Colab interface.
# 2.  **Navigate** to the `/content/echoscene/` directory.
# 3.  **Locate** `vis_folder.zip`.
# 4.  **Right-click** on the `vis_folder.zip` file.
# 5.  Select **Download**.
